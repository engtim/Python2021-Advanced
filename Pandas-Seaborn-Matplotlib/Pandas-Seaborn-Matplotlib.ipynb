# %%
import pandas as pd

# %%
#reading the excel file
df = pd.read_excel('kenyagazettedregisterperpollingstation2017.xlsx')

# %%
#displaying data from excel file 
df
# Out:
#        COUNTY CODE COUNTY NAME  CONSTITUENCY CODE CONSTITUENCY NAME  CAW CODE  \
# 0              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# 1              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# 2              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# 3              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# 4              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# ...            ...         ...                ...               ...       ...
# 40879         49.0     PRISONS              292.0           PRISONS    1451.0
# 40880         49.0     PRISONS              292.0           PRISONS    1451.0
# 40881         49.0     PRISONS              292.0           PRISONS    1451.0
# 40882         49.0     PRISONS              292.0           PRISONS    1451.0
# 40883          NaN         NaN                NaN               NaN       NaN
#
# ...

# %%
#displaying information in the dataset 
df.info
# Out:
# <bound method DataFrame.info of        COUNTY CODE COUNTY NAME  CONSTITUENCY CODE CONSTITUENCY NAME  CAW CODE  \
# 0              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# 1              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# 2              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# 3              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# 4              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# ...            ...         ...                ...               ...       ...
# 40879         49.0     PRISONS              292.0           PRISONS    1451.0
# 40880         49.0     PRISONS              292.0           PRISONS    1451.0
# 40881         49.0     PRISONS              292.0           PRISONS    1451.0
# 40882         49.0     PRISONS              292.0           PRISONS    1451.0
# 40883          NaN         NaN                NaN               NaN       NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40884 entries, 0 to 40883
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   COUNTY CODE                     40883 non-null  float64
#  1   COUNTY NAME                     40883 non-null  object
#  2   CONSTITUENCY CODE               40883 non-null  float64
#  3   CONSTITUENCY NAME               40883 non-null  object
#  4   CAW CODE                        40883 non-null  float64
#  5   CAW_NAME                        40883 non-null  object
#  6   REGISTRATION CENTRE CODE        40883 non-null  float64
#  7   REGISTRATION CENTRE NAME        24703 non-null  object
#  8   VOTERS PER REGISTRATION CENTRE  24703 non-null  float64
#  9   POLLING STATION CODE            40883 non-null  float64
#  10  POLLING STATION NAME            40883 non-null  object
#  11  VOTERS PER POLLING STATION      40884 non-null  int64
# ...

# %%
#Displaying table framework
df.shape
# Out:
# (40884, 12)

# %%
#Dropping one column
df.drop('CAW CODE',axis=1)
# Out:
#        COUNTY CODE COUNTY NAME  CONSTITUENCY CODE CONSTITUENCY NAME  \
# 0              1.0     MOMBASA                1.0         CHANGAMWE
# 1              1.0     MOMBASA                1.0         CHANGAMWE
# 2              1.0     MOMBASA                1.0         CHANGAMWE
# 3              1.0     MOMBASA                1.0         CHANGAMWE
# 4              1.0     MOMBASA                1.0         CHANGAMWE
# ...            ...         ...                ...               ...
# 40879         49.0     PRISONS              292.0           PRISONS
# 40880         49.0     PRISONS              292.0           PRISONS
# 40881         49.0     PRISONS              292.0           PRISONS
# 40882         49.0     PRISONS              292.0           PRISONS
# 40883          NaN         NaN                NaN               NaN
#
#          CAW_NAME  REGISTRATION CENTRE CODE     REGISTRATION CENTRE NAME  \
# 0      PORT REITZ                       1.0          BOMU PRIMARY SCHOOL
# ...

# %%
#Displaying dataset after dropping column
df
# Out:
#        COUNTY CODE COUNTY NAME  CONSTITUENCY CODE CONSTITUENCY NAME  CAW CODE  \
# 0              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# 1              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# 2              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# 3              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# 4              1.0     MOMBASA                1.0         CHANGAMWE       1.0
# ...            ...         ...                ...               ...       ...
# 40879         49.0     PRISONS              292.0           PRISONS    1451.0
# 40880         49.0     PRISONS              292.0           PRISONS    1451.0
# 40881         49.0     PRISONS              292.0           PRISONS    1451.0
# 40882         49.0     PRISONS              292.0           PRISONS    1451.0
# 40883          NaN         NaN                NaN               NaN       NaN
#
# ...

# %%
df = df.drop('CAW CODE',axis=1)

# %%
#Displaying rows in dataset
df.head()
# Out:
#    COUNTY CODE COUNTY NAME  CONSTITUENCY CODE CONSTITUENCY NAME    CAW_NAME  \
# 0          1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 1          1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 2          1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 3          1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 4          1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
#
#    REGISTRATION CENTRE CODE REGISTRATION CENTRE NAME  \
# 0                       1.0      BOMU PRIMARY SCHOOL
# 1                       1.0                      NaN
# 2                       1.0                      NaN
# 3                       1.0                      NaN
# 4                       1.0                      NaN
#
#    VOTERS PER REGISTRATION CENTRE  POLLING STATION CODE POLLING STATION NAME  \
# 0                          9625.0          1.001000e+12  BOMU PRIMARY SCHOOL
# ...

# %%
#Displaying top 15 rows in the dataset
df.head(15)
# Out:
#     COUNTY CODE COUNTY NAME  CONSTITUENCY CODE CONSTITUENCY NAME    CAW_NAME  \
# 0           1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 1           1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 2           1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 3           1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 4           1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 5           1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 6           1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 7           1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 8           1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 9           1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# 10          1.0     MOMBASA                1.0         CHANGAMWE  PORT REITZ
# ...

# %%
df.tail()
# Out:
#        COUNTY CODE COUNTY NAME  CONSTITUENCY CODE CONSTITUENCY NAME CAW_NAME  \
# 40879         49.0     PRISONS              292.0           PRISONS  PRISONS
# 40880         49.0     PRISONS              292.0           PRISONS  PRISONS
# 40881         49.0     PRISONS              292.0           PRISONS  PRISONS
# 40882         49.0     PRISONS              292.0           PRISONS  PRISONS
# 40883          NaN         NaN                NaN               NaN      NaN
#
#        REGISTRATION CENTRE CODE     REGISTRATION CENTRE NAME  \
# 40879                     112.0       KAMITI MEDIUM PRISON
# 40880                     113.0         KAMITI MAIN PRISON
# 40881                     116.0  NAIROBI REMAND/ALLOCATION
# 40882                     118.0            KILGORIS PRISON
# 40883                       NaN      TOTAL REGISTERED VOTERS
#
#        VOTERS PER REGISTRATION CENTRE  POLLING STATION CODE  \
# 40879                           160.0          4.929215e+13
# ...

# %%
#Displaying the last 10 rows in dataset
df.tail(10)
# Out:
#        COUNTY CODE COUNTY NAME  CONSTITUENCY CODE CONSTITUENCY NAME CAW_NAME  \
# 40874         49.0     PRISONS              292.0           PRISONS  PRISONS
# 40875         49.0     PRISONS              292.0           PRISONS  PRISONS
# 40876         49.0     PRISONS              292.0           PRISONS  PRISONS
# 40877         49.0     PRISONS              292.0           PRISONS  PRISONS
# 40878         49.0     PRISONS              292.0           PRISONS  PRISONS
# 40879         49.0     PRISONS              292.0           PRISONS  PRISONS
# 40880         49.0     PRISONS              292.0           PRISONS  PRISONS
# 40881         49.0     PRISONS              292.0           PRISONS  PRISONS
# 40882         49.0     PRISONS              292.0           PRISONS  PRISONS
# 40883          NaN         NaN                NaN               NaN      NaN
#
#        REGISTRATION CENTRE CODE     REGISTRATION CENTRE NAME  \
# ...

# %%
#Displaying two specific columns
df['REGISTRATION CENTRE CODE']
# Out:
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
#          ...
# 40879    112.0
# 40880    113.0
# 40881    116.0
# 40882    118.0
# 40883      NaN
# Name: REGISTRATION CENTRE CODE, Length: 40884, dtype: float64

# %%
#Displaying three specific columns
df[['COUNTY CODE', 'COUNTY NAME', 'CONSTITUENCY CODE']]
# Out:
#        COUNTY CODE COUNTY NAME  CONSTITUENCY CODE
# 0              1.0     MOMBASA                1.0
# 1              1.0     MOMBASA                1.0
# 2              1.0     MOMBASA                1.0
# 3              1.0     MOMBASA                1.0
# 4              1.0     MOMBASA                1.0
# ...            ...         ...                ...
# 40879         49.0     PRISONS              292.0
# 40880         49.0     PRISONS              292.0
# 40881         49.0     PRISONS              292.0
# 40882         49.0     PRISONS              292.0
# 40883          NaN         NaN                NaN
#
# [40884 rows x 3 columns]
